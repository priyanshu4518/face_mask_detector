# %%
import numpy as np
import pandas as pd

# %%
# !pip install kaggle
from google.colab import files
files.upload()
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d omkargurav/face-mask-dataset
# !unzip face-mask-dataset.zip
# Out:
# ...
#      <input type="file" id="files-97d694f4-12ef-471b-86eb-9dbb304a694e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97d694f4-12ef-471b-86eb-9dbb304a694e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import cv2
path='data'
categories=['with_mask','without_mask']
data=[]
label=[]
for category in categories:
  path2=os.path.join(path,category)
  label=categories.index(category)
  for image in os.listdir(path2):
    image_path=os.path.join(path2,image)
    image=cv2.imread(image_path)
    image=cv2.resize(image,(224,224))
    data.append([image,label])

# %%
len(data)
data=data[:4000]

# %%
import random
random.shuffle(data)

# %%
x=[]
y=[]
for feature,label in data:
  x.append(feature)
  y.append(label)

# %%
x=np.array(x)
y=np.array(y)

# %%
x.shape
# Out:
# (4000, 224, 224, 3)

# %%
y.shape
# Out:
# (4000,)

# %%
x=x/255

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
from keras.applications.vgg16 import VGG16

# %%
vgg=VGG16()
# Out:
# ...
# 553467096/553467096 [==============================] - 5s 0us/step

# %%
from keras import Sequential

# %%
model = Sequential()
for layers in vgg.layers[:-1]:
  model.add(layers)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
for layer in model.layers:
  layer.trainable=False

# %%
from keras.layers import Dense
import matplotlib.pyplot as plt

# %%
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 113/113 [==============================] - 77s 675ms/step - loss: 0.2317 - accuracy: 0.9275 - val_loss: 0.1794 - val_accuracy: 0.9300
# Epoch 2/10
# 113/113 [==============================] - 75s 665ms/step - loss: 0.1634 - accuracy: 0.9397 - val_loss: 0.1469 - val_accuracy: 0.9525
# Epoch 3/10
# 113/113 [==============================] - 75s 661ms/step - loss: 0.1262 - accuracy: 0.9514 - val_loss: 0.1308 - val_accuracy: 0.9500
# Epoch 4/10
# 113/113 [==============================] - 75s 665ms/step - loss: 0.1092 - accuracy: 0.9600 - val_loss: 0.1125 - val_accuracy: 0.9575
# Epoch 5/10
# 113/113 [==============================] - 74s 658ms/step - loss: 0.1012 - accuracy: 0.9650 - val_loss: 0.1271 - val_accuracy: 0.9525
# Epoch 6/10
# 113/113 [==============================] - 75s 661ms/step - loss: 0.0951 - accuracy: 0.9672 - val_loss: 0.1011 - val_accuracy: 0.9650
# Epoch 7/10
# ...

# %%
def predict(img,model):
  img=cv2.resize(img,(224,224))
  y_pred=model.predict(img.reshape(1,224,224,3))
  return y_pred[0][0]

# %%
img=cv2.imread('mask_1.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 127ms/step
# with_mask

# %%
img=cv2.imread('mask_2.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 127ms/step
# with_mask

# %%
img=cv2.imread('mask_3.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 109ms/step
# with_mask

# %%
img=cv2.imread('mask_4.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 109ms/step
# with_mask

# %%
img=cv2.imread('mask_5.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 127ms/step
# with_mask

# %%
img=cv2.imread('img_1.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 130ms/step
# without_mask

# %%
img=cv2.imread('img_4.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 118ms/step
# without_mask

# %%
img=cv2.imread('img_5.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 125ms/step
# with_mask

# %%
img=cv2.imread('img_6.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 127ms/step
# without_mask

# %%
img=cv2.imread('img_7.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 128ms/step
# with_mask

# %%
img=cv2.imread('img_9.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
if predict(img,model)>0.5:
  print('without_mask')
else:
  print('with_mask')
# Out:
# 1/1 [==============================] - 0s 140ms/step
# without_mask

# %%
import pickle
pickle.dump(model,open('model.pkl','wb'))
